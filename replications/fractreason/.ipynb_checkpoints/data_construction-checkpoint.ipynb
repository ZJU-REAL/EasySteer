# %%
import os
import pandas as pd

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
model_path = "/home/shenyl/hf/model/Qwen/Qwen2.5-1.5B-Instruct/"
file_path = "/home/xhl/eval/my_eval/data/math500/test.jsonl"
df = pd.read_json(file_path, lines=True)
problem_list = df["problem"][:20]

slow_thinking = "Walk me through your complete reasoning process step by step. Output as many procedures as you can."
fast_thinking = "Please directly answer the question."

texts = []

for prob in problem_list:
    texts.append(f"""<|im_start|>user
{prob}
{slow_thinking}<|im_end|>
<|im_start|>assistant
That""")

for prob in problem_list:
    texts.append(f"""<|im_start|>user
{prob}
{fast_thinking}<|im_end|>
<|im_start|>assistant
That""")

# %%
from vllm import LLM
import easysteer.hidden_states as hs

llm = LLM(
    model=model_path,
    tensor_parallel_size=1,
    enforce_eager=True,
    enable_prefix_caching=False,
    enable_chunked_prefill=False
)
all_hidden_states, outputs = hs.get_all_hidden_states_generate(llm, texts)
# Out:
# INFO 01-11 22:03:53 [utils.py:253] non-default args: {'enable_prefix_caching': False, 'disable_log_stats': True, 'enforce_eager': True, 'enable_chunked_prefill': False, 'model': '/home/shenyl/hf/model/Qwen/Qwen2.5-1.5B-Instruct/'}
# INFO 01-11 22:03:53 [model.py:514] Resolved architecture: Qwen2ForCausalLM
# INFO 01-11 22:03:53 [model.py:1661] Using max model len 32768
# WARNING 01-11 22:03:53 [arg_utils.py:1900] This model does not officially support disabling chunked prefill. Disabling this manually may cause the engine to crash or produce incorrect outputs.
# WARNING 01-11 22:03:56 [vllm.py:625] Enforce eager set, overriding optimization level to -O0
# INFO 01-11 22:03:56 [vllm.py:725] Cudagraph is disabled under eager mode
# (EngineCore_DP0 pid=138328) INFO 01-11 22:03:56 [core.py:94] Initializing a V1 LLM engine (v0.1.dev12297+gb744aa686) with config: model='/home/shenyl/hf/model/Qwen/Qwen2.5-1.5B-Instruct/', speculative_config=None, tokenizer='/home/shenyl/hf/model/Qwen/Qwen2.5-1.5B-Instruct/', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False), seed=0, served_model_name=/home/shenyl/hf/model/Qwen/Qwen2.5-1.5B-Instruct/, enable_prefix_caching=False, enable_chunked_prefill=False, pooler_config=None, compilation_config={'level': None, 'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'splitting_ops': [], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [32768], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'eliminate_noops': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False}, 'local_cache_dir': None}
# (EngineCore_DP0 pid=138328) INFO 01-11 22:03:58 [parallel_state.py:1203] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://10.130.138.46:45815 backend=nccl
# (EngineCore_DP0 pid=138328) INFO 01-11 22:03:58 [parallel_state.py:1411] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:00 [gpu_model_runner.py:3628] Starting to load model /home/shenyl/hf/model/Qwen/Qwen2.5-1.5B-Instruct/...
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:00 [cuda.py:351] Using FLASH_ATTN attention backend out of potential backends: ('FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION')
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:01 [default_loader.py:308] Loading weights took 0.87 seconds
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:01 [capture_model_runner_mixin.py:113] [Capture] Wrapped 28 decoder layers for hidden states capture
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:02 [gpu_model_runner.py:3731] Model loading took 2.8876 GiB memory and 1.259240 seconds
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:04 [gpu_worker.py:376] Available KV cache memory: 37.72 GiB
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:04 [kv_cache_utils.py:1309] GPU KV cache size: 1,412,400 tokens
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:04 [kv_cache_utils.py:1314] Maximum concurrency for 32,768 tokens per request: 43.10x
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:04 [core.py:260] init engine (profile, create kv cache, warmup model) took 2.43 seconds
# (EngineCore_DP0 pid=138328) WARNING 01-11 22:04:05 [vllm.py:632] Inductor compilation was disabled by user settings,Optimizations settings that are only active duringInductor compilation will be ignored.
# (EngineCore_DP0 pid=138328) INFO 01-11 22:04:05 [vllm.py:725] Cudagraph is disabled under eager mode
# INFO 01-11 22:04:05 [llm.py:361] Supported tasks: ['generate']
# Adding requests:   0%|          | 0/40 [00:00<?, ?it/s]
# Processed prompts:   0%| | 0/40 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, outp

# %%
from easysteer.steer import extract_pca_control_vector
control_vector = extract_pca_control_vector(
    all_hidden_states=all_hidden_states,
    positive_indices=list(range(20)), 
    negative_indices=list(range(20,40)),
    model_type="qwen2.5",
    token_pos=-1,
    normalize=True,
    method="center"
)
control_vector.export_gguf("MATH500.gguf")
# Out:
# Computing PCA directions:   0%|          | 0/28 [00:00<?, ?it/s]
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 0: PCA on centered data explains 91.40128% of the variance
# [2026-01-11 22:04:08] INFO pca.py:169: Layer 0: Direction corrected (flipped)
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 1: PCA on centered data explains 89.63355% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 2: PCA on centered data explains 90.07514% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 3: PCA on centered data explains 89.11943% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 4: PCA on centered data explains 89.48711% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 5: PCA on centered data explains 86.34247% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 6: PCA on centered data explains 83.49532% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 7: PCA on centered data explains 83.14339% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 8: PCA on centered data explains 81.67219% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 9: PCA on centered data explains 80.18944% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 10: PCA on centered data explains 81.24851% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 11: PCA on centered data explains 80.56940% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 12: PCA on centered data explains 82.02959% of the variance
# [2026-01-11 22:04:08] INFO pca.py:169: Layer 12: Direction corrected (flipped)
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 13: PCA on centered data explains 81.06200% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 14: PCA on centered data explains 80.05905% of the variance
# [2026-01-11 22:04:08] INFO pca.py:169: Layer 14: Direction corrected (flipped)
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 15: PCA on centered data explains 78.00652% of the variance
# [2026-01-11 22:04:08] INFO pca.py:169: Layer 15: Direction corrected (flipped)
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 16: PCA on centered data explains 75.09963% of the variance
# [2026-01-11 22:04:08] INFO pca.py:169: Layer 16: Direction corrected (flipped)
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 17: PCA on centered data explains 73.66262% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 18: PCA on centered data explains 71.75695% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 19: PCA on centered data explains 72.05555% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 20: PCA on centered data explains 66.29729% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 21: PCA on centered data explains 63.83733% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 22: PCA on centered data explains 59.20193% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 23: PCA on centered data explains 57.72367% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 24: PCA on centered data explains 57.25974% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 25: PCA on centered data explains 57.52657% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 26: PCA on centered data explains 55.53575% of the variance
# [2026-01-11 22:04:08] INFO pca.py:114: Layer 27: PCA on centered data explains 52.84832% of the variance
# [2026-01-11 22:04:08] INFO pca.py:169: Layer 27: Direction corrected (flipped)
# [2026-01-11 22:04:08] INFO gguf_writer.py:102: gguf: This GGUF file is for Little Endian only
# [2026-01-11 22:04:08] WARNING gguf_writer.py:274: Duplicated key name 'controlvector.method', overwriting it with new value 'center' of type STRING
# [2026-01-11 22:04:08] INFO gguf_writer.py:181: Writing the following files:
# [2026-01-11 22:04:08] INFO gguf_writer.py:186: MATH500.gguf: n_tensors = 28, total_size = 172.0K
